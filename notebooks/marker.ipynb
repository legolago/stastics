# %%
# Matplotlibで使用できるマーカー形状の一覧

# 基本的なマーカーシンボル
markers_basic = {
    'o': '円 (circle)',
    '.': '点 (point)',
    ',': 'ピクセル (pixel)',
    'v': '下向き三角 (triangle_down)',
    '^': '上向き三角 (triangle_up)',
    '<': '左向き三角 (triangle_left)',
    '>': '右向き三角 (triangle_right)',
    '1': '下向きトライデント (tri_down)',
    '2': '上向きトライデント (tri_up)',
    '3': '左向きトライデント (tri_left)',
    '4': '右向きトライデント (tri_right)',
    's': '四角 (square)',
    'p': '五角形 (pentagon)',
    '*': '星 (star)',
    'h': '六角形1 (hexagon1)',
    'H': '六角形2 (hexagon2)',
    '+': 'プラス (plus)',
    'x': 'バツ (x)',
    'D': 'ダイヤモンド (diamond)',
    'd': '細いダイヤモンド (thin_diamond)',
    '|': '垂直線 (vline)',
    '_': '水平線 (hline)'
}

# 特殊なマーカー
markers_special = {
    '$...$': 'マス文字 (例: "$\clubsuit$"でクラブマーク)',
    '(numsides, style, angle)': 'カスタム正多角形 (例: (5,0,0)で五角形)',
    'None, " " または ""': 'マーカーなし',
    'None': 'マーカーなし'
}

# カスタムマーカーの例
custom_markers = {
    '(5, 0, 0)': '五角形 (辺=5, スタイル=正多角形, 角度=0度)',
    '(5, 1, 0)': '五角形の星 (辺=5, スタイル=星形, 角度=0度)',
    '(6, 0, 0)': '六角形 (辺=6, スタイル=正多角形, 角度=0度)',
}

# 数学記号や特殊文字マーカーの例
math_markers = {
    '$\u2665$': 'ハート',  # ♥
    '$\u2660$': 'スペード',  # ♠
    '$\u2663$': 'クラブ',  # ♣
    '$\u2666$': 'ダイヤ',  # ♦
    '$\u266B$': '音符',  # ♫
    '$\u263A$': 'スマイル',  # ☺
    '$\u2605$': '星',  # ★
    '$\oplus$': '丸付きプラス',
    '$\otimes$': '丸付きバツ',
    '$\infty$': '無限大',
    '$\Sigma$': 'シグマ記号',
    '$\Omega$': 'オメガ記号'
}

# -----------------------------------------------
# コレスポンデンス分析で使うなら以下がおすすめ
# -----------------------------------------------

# 2つのカテゴリを区別するのに適した組み合わせ例
recommended_pairs = [
    {'イメージ': 'o', 'ブランド': 'D'},  # 円とダイヤモンド
    {'イメージ': 's', 'ブランド': 'o'},  # 四角と円
    {'イメージ': '^', 'ブランド': 'v'},  # 上三角と下三角
    {'イメージ': '*', 'ブランド': 's'},  # 星と四角
    {'イメージ': 'p', 'ブランド': 'h'},  # 五角形と六角形
    {'イメージ': '+', 'ブランド': 'x'},  # プラスとバツ
    {'イメージ': 'D', 'ブランド': 'p'},  # ダイヤモンドと五角形
    {'イメージ': '<', 'ブランド': '>'},  # 左三角と右三角
]

# 以下のようにコード内で設定します:
"""
# カスタムマーカー - どの組み合わせでも使えます
markers = {
    'イメージ': '*',   # 星
    'ブランド': 's',   # 四角
}
"""

# -----------------------------------------------
# サンプルコード: すべてのマーカーを表示する
# -----------------------------------------------


import matplotlib.pyplot as plt
import japanize_matplotlib
import numpy as np

def plot_markers():
    # 基本マーカーを表示
    fig, ax = plt.subplots(figsize=(10, 8))
    x = np.arange(len(markers_basic))
    y = [0] * len(markers_basic)
    
    for i, (marker, name) in enumerate(markers_basic.items()):
        ax.plot(i, 0, marker=marker, markersize=10, color='blue')
        ax.text(i, -0.1, f"'{marker}': {name}", ha='center', va='top', rotation=45)
    
    ax.set_xlim(-1, len(markers_basic))
    ax.set_ylim(-0.5, 0.5)
    ax.set_title('Matplotlib マーカー一覧')
    ax.axis('off')
    plt.tight_layout()
    plt.show()

# このコメントを外して実行すると、使用可能なマーカーを表示します
plot_markers()
